# %%
# tamrin 1

# %%
a=True
b=False
c=""
d="k"
e=0
f=1
g=0.5
h="sss"
i="False"
j=True

# %%
a or b
# Out:
# True

# %%
b  or c
# Out:
# ''

# %%
c or d
# Out:
# 'k'

# %%
d or e
# Out:
# 'k'

# %%
e or f
# Out:
# 1

# %%
f or g
# Out:
# 1

# %%
g or h
# Out:
# 0.5

# %%
h or i
# Out:
# 'sss'

# %%
i or j
# Out:
# 'False'

# %%
j or b
# Out:
# True

# %%
a and b
# Out:
# False

# %%
b and c
# Out:
# False

# %%
c and d
# Out:
# ''

# %%
d and e
# Out:
# 0

# %%
e and f
# Out:
# 0

# %%
f and g
# Out:
# 0.5

# %%
g and h
# Out:
# 'sss'

# %%
h and i
# Out:
# 'False'

# %%
i and j
# Out:
# True

# %%
j and c
# Out:
# ''

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
not c
# Out:
# True

# %%
not d
# Out:
# False

# %%
not e
# Out:
# True

# %%
not f
# Out:
# False

# %%
not g
# Out:
# False

# %%
not  h
# Out:
# False

# %%
not i
# Out:
# False

# %%
not j
# Out:
# False

# %%
# tamrin 2

# %%
a is b
# Out:
# False

# %%
b is c
# Out:
# False

# %%
c is d
# Out:
# False

# %%
d is e
# Out:
# False

# %%
e is f
# Out:
# False

# %%
f is g
# Out:
# False

# %%
g is h
# Out:
# False

# %%
h is i
# Out:
# False

# %%
i is j
# Out:
# False

# %%
j is d
# Out:
# False

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# str

# %%
type(e)
# Out:
# int

# %%
type(f)
# Out:
# int

# %%
type(g)
# Out:
# float

# %%
type(h)
# Out:
# str

# %%
type(i)
# Out:
# str

# %%
type(j)
# Out:
# bool

# %%
# tamrin 4

# %%
def jam(a,b):
    return a+b
    
def tafrigh(a,b):
    return a-b
    
def zarb(a,b):
    return a*b

def taghsim(a,b):
    return a/b

# %%
jam(1,2)
# Out:
# 3

# %%
jam(2,3)
# Out:
# 5

# %%
jam(175,2)
# Out:
# 177

# %%
tafrigh(1,2)
# Out:
# -1

# %%
tafrigh(4,3)
# Out:
# 1

# %%
tafrigh(158,4)
# Out:
# 154

# %%
zarb(2,4)
# Out:
# 8

# %%
zarb(3,6)
# Out:
# 18

# %%
zarb(135,15)
# Out:
# 2025

# %%
taghsim(5,8)
# Out:
# 0.625

# %%
taghsim(700,10)
# Out:
# 70.0

# %%
taghsim(2025,9)
# Out:
# 225.0

# %%
taghsim(2025,13)
# Out:
# 155.76923076923077
