# %%
def myF1():
    return 5

# %%
def myF2(x):
    return x

# %%
def myF3(a,b,c,x):
    y = (a*(x**2))+(b*x)+c
    return y

# %%
def myF4(a,x,b,c,d):
    y= (a*(x**3))+(b*(x**2))+(c*x)+d
    return y

# %%
def myF5(a, x):
    y= a**x
    return y

# %%
def myF6(x):
    y= abs(x)
    return -y

# %%
def myF7(w,a,d,f):
    y= (w-a)*(d/f)
    return y

# %%
def myF8(a,x,b,z):
    y= (a*x)+(b*z)
    return y

# %%
myF1()
# Out:
# 5

# %%
myF2(66)
# Out:
# 66

# %%
myF3(5,6,8,2)
# Out:
# 40

# %%
myF4(1,2,4,5,6)
# Out:
# 40

# %%
myF5(5,7)
# Out:
# 78125

# %%
myF6(-52)
# Out:
# -52

# %%
myF6(754)
# Out:
# -754

# %%
myF7(4,5,6,2)
# Out:
# -3.0

# %%
myF8(8,2,4,6)
# Out:
# 40
